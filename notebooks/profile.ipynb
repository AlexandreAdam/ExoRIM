# %%
import pstats

# %%
p = pstats.Stats('../profile.txt')
p.strip_dirs().sort_stats(-1).sort_stats('time', 'cumulative').print_stats(.5, 'init')
# Out:
# Fri Jul 10 13:52:16 2020    ../profile.txt
#
#          15783246 function calls (15649412 primitive calls) in 54.733 seconds
#
#    Ordered by: internal time, cumulative time
#    List reduced from 10205 to 5103 due to restriction <0.5>
#    List reduced from 5103 to 532 due to restriction <'init'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     28916    0.051    0.000    0.174    0.000 tensor_shape.py:742(__init__)
#     51280    0.045    0.000    0.045    0.000 backprop.py:103(__init__)
#     31049    0.037    0.000    0.041    0.000 ops.py:6405(__init__)
#     46174    0.037    0.000    0.041    0.000 tensor_shape.py:185(__init__)
#     23247    0.029    0.000    0.036    0.000 contextlib.py:59(__init__)
#         2    0.026    0.013    0.027    0.014 definitions.py:115(one_sided_DFTM)
#    109611    0.024    0.000    0.051    0.000 context.py:492(ensure_initialized)
#      1240    0.023    0.000    0.127    0.000 nn_ops.py:503(__init__)
# ...
